# %%
import os
import optuna
os.chdir('../..')
print(os.getcwd())
# Out:
# /home/trath/Code/nlpvise/src

# %%
from training_pipeline import TrainingPipeline
from models.bilstm import BiLSTM

# %%
training_pipeline = TrainingPipeline(max_epochs=5)

# %% [markdown]
# **Load the data and split train test set**

# %%
training_pipeline.load_data()
# Out:
# Data loaded successfully.
# Train/Test split completed.

# %% [markdown]
# **Optuna ConvNet**

# %%
model = BiLSTM(input_size=768)

# %%
# 1 for testing, use at least 20-50 trials.
study, best = training_pipeline.optimize_hyperparameters(model, n_trials=5)
# Out:
# [I 2025-04-18 05:47:35,599] A new study created in memory with name: no-name-4dfe6861-78e7-4854-8ee4-f32657ea6fe4
# Using device: cpu.
#   0%|          | 0/5 [00:00<?, ?it/s]
# -- Trial number 0 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss      dur
# -------  -----------  ------------  -----------  ------------  -------
#       1       0.7094        0.5527       0.7211        0.5194  27.1324
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7270        0.5180       0.7312        0.5145  37.0828
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7362        0.5109       0.7394        0.5067  53.0846
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7418        0.5046       0.7437        0.5020  28.2958
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7455        0.5007       0.7468        0.4989  23.8971
# [I 2025-04-18 05:50:28,196] Trial 0 finished with values: [0.7468184490604645, 0.0013677965909180134] and parameters: {'learning_rate': 1e-05}.
# -- Trial number 1 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss      dur
# -------  -----------  ------------  -----------  ------------  -------
#       1       0.6512        1.7774       0.6334        1.7871  26.1653
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.6508        1.7763       0.6419        1.6872  90.0015
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.6517        1.7543       0.6571        1.3049  80.6959
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.6511        1.7903       0.6799        1.6622  91.8189
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.6519        1.7626       0.6717        1.9392  90.7200
# [I 2025-04-18 05:56:59,414] Trial 1 finished with values: [0.6717227363421309, 0.0198197242765078] and parameters: {'learning_rate': 0.1}.
# -- Trial number 2 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss      dur
# -------  -----------  ------------  -----------  ------------  -------
#       1       0.6712        1.9210       0.6719        1.8940  48.9993
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.6739        1.8840       0.6712        1.8881  48.3004
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.6733        1.8480       0.6723        1.8420  59.4078
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.6726        1.8353       0.6765        1.7979  57.8208
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.6736        1.7938       0.6743        1.7753  55.1251
# [I 2025-04-18 06:01:40,751] Trial 2 finished with values: [0.6742897352449644, 0.000641403310124522] and parameters: {'learning_rate': 1e-06}.
# -- Trial number 3 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss      dur
# -------  -----------  ------------  -----------  ------------  -------
#       1       0.6727        1.2076       0.6665        1.0296  31.5885
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.6669        1.0027       0.6658        0.9730  55.1718
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.6660        0.9563       0.6680        0.9123  49.4732
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.6662        0.9077       0.6665        0.8788  98.2586
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.6667        0.8631       0.6683        0.8283  57.6838
# [I 2025-04-18 06:06:48,886] Trial 3 finished with values: [0.6683062436635172, 0.0016183584750099067] and parameters: {'learning_rate': 0.0001}.
# -- Trial number 4 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss      dur
# -------  -----------  ------------  -----------  ------------  -------
#       1       0.6641        0.8369       0.6669        0.8342  56.4558
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.6670        0.8279       0.6685        0.8196  55.8920
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.6661        0.8229       0.6671        0.8218  57.2176
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.6665        0.8118       0.6653        0.8215  59.1459
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.6660        0.8200       0.6709        0.8134  65.5098
# [I 2025-04-18 06:11:59,776] Trial 4 finished with values: [0.6708778719602242, 0.004882096375026901] and parameters: {'learning_rate': 1e-05}.
#
# Best trial
#  - Validation accuracy: 0.7468184490604645
#  - Generalization gap: 0.0013677965909180134
# Parameters:
# learning_rate: 1e-05
