# %%
import os
import optuna
os.chdir('../..')
print(os.getcwd())
# Out:
# /home/trath/Code/nlpvise/src

# %%
from training_pipeline import TrainingPipeline
from models.convnet import ConvNet

# %%
training_pipeline = TrainingPipeline()

# %% [markdown]
# **Load the data and split train test set**

# %%
training_pipeline.load_data()
# Out:
# Data loaded successfully.
# Train/Test split completed.

# %% [markdown]
# **Optuna ConvNet**

# %%
model = ConvNet(input_size=768)

# %%
# 1 for testing, use at least 20-50 trials.
study, best = training_pipeline.optimize_hyperparameters(model, n_trials=5)
# Out:
# [I 2025-04-18 06:23:10,782] A new study created in memory with name: no-name-a5e936bf-df2c-4412-89af-79147c5cd63b
# Using device: cpu.
#   0%|          | 0/5 [00:00<?, ?it/s]
# -- Trial number 0 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss      dur
# -------  -----------  ------------  -----------  ------------  -------
#       1       0.7163        0.5482       0.7322        0.5144  13.2226
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7381        0.5089       0.7421        0.5035  12.8101
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7448        0.5010       0.7475        0.4980  15.2371
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7497        0.4963       0.7519        0.4939  21.9054
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7535        0.4925       0.7556        0.4904  20.2117
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7564        0.4893       0.7580        0.4875  22.2922
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7587        0.4867       0.7600        0.4852  19.8660
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7604        0.4846       0.7614        0.4833  17.7007
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7616        0.4829       0.7625        0.4817  18.1584
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7628        0.4814       0.7635        0.4803  27.2351
# [I 2025-04-18 06:26:45,265] Trial 0 finished with values: [0.7635444491252761, 0.000784112329465847] and parameters: {'learning_rate': 1e-05}.
# -- Trial number 1 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss      dur
# -------  -----------  ------------  -----------  ------------  -------
#       1       0.7194        1.0963       0.7166        0.5201  26.8054
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7204        0.5206       0.7166        0.5204  17.0940
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7202        0.5207       0.7166        0.5205  24.8999
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7201        0.5207       0.7166        0.5205  28.9577
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7201        0.5207       0.7166        0.5205  26.9467
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7201        0.5207       0.7166        0.5205  26.3042
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7201        0.5207       0.7166        0.5206  24.2639
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7201        0.5207       0.7166        0.5206  18.6575
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7201        0.5207       0.7166        0.5206  15.6095
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7201        0.5207       0.7166        0.5206  17.5348
# [I 2025-04-18 06:31:02,008] Trial 1 finished with values: [0.7165977658545167, 0.0034768847632314914] and parameters: {'learning_rate': 0.1}.
# -- Trial number 2 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss      dur
# -------  -----------  ------------  -----------  ------------  -------
#       1       0.7174        0.5211       0.7166        0.5205  10.6949
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7174        0.5211       0.7166        0.5205  10.8594
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7174        0.5211       0.7166        0.5205  11.5909
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7174        0.5211       0.7166        0.5205  10.8531
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7174        0.5211       0.7166        0.5205  11.6376
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7174        0.5211       0.7166        0.5205  22.7208
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7174        0.5211       0.7166        0.5205  0.3799
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7174        0.5211       0.7166        0.5205  11.0942
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7174        0.5211       0.7166        0.5205  10.7034
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7174        0.5211       0.7166        0.5205  10.9422
# [I 2025-04-18 06:33:21,721] Trial 2 finished with values: [0.7165977658545167, 0.0008322853592790391] and parameters: {'learning_rate': 1e-06}.
# -- Trial number 3 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss     dur
# -------  -----------  ------------  -----------  ------------  ------
#       1       0.7180        0.5208       0.7179        0.5200  1.2973
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7184        0.5204       0.7179        0.5197  11.4135
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7191        0.5202       0.7212        0.5195  11.4193
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7214        0.5201       0.7212        0.5194  10.3367
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7214        0.5200       0.7212        0.5194  11.0267
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7214        0.5199       0.7212        0.5193  10.9482
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7214        0.5199       0.7212        0.5193  11.2564
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7214        0.5199       0.7212        0.5193  20.9861
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7214        0.5199       0.7212        0.5193  3.5046
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7214        0.5199       0.7212        0.5193  10.8946
# [I 2025-04-18 06:35:24,015] Trial 3 finished with values: [0.7212040127586095, 0.00020856210901587513] and parameters: {'learning_rate': 0.0001}.
# -- Trial number 4 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss      dur
# -------  -----------  ------------  -----------  ------------  -------
#       1       0.7214        0.5199       0.7212        0.5193  11.2068
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7214        0.5199       0.7212        0.5193  10.7330
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7214        0.5199       0.7212        0.5193  12.4437
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7214        0.5199       0.7212        0.5193  11.1699
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7214        0.5199       0.7212        0.5193  11.0536
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7214        0.5199       0.7212        0.5193  11.1703
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7214        0.5199       0.7212        0.5193  10.8314
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7214        0.5199       0.7212        0.5193  10.9038
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7214        0.5199       0.7212        0.5193  11.8104
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7214        0.5199       0.7212        0.5193  11.0493
# [I 2025-04-18 06:37:34,966] Trial 4 finished with values: [0.7212040127586095, 0.00020856210901587513] and parameters: {'learning_rate': 1e-05}.
#
# Best trial
#  - Validation accuracy: 0.7635444491252761
#  - Generalization gap: 0.000784112329465847
# Parameters:
# learning_rate: 1e-05
