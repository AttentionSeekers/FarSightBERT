# %%
import os
import optuna
os.chdir('../..')
print(os.getcwd())
# Out:
# /home/trath/Code/nlpvise/src

# %%
from training_pipeline import TrainingPipeline
from models.convnet import ConvNet

# %%
training_pipeline = TrainingPipeline()

# %% [markdown]
# **Load the data and split train test set**

# %%
training_pipeline.load_data()
# Out:
# Data loaded successfully.
# Train/Test split completed.

# %% [markdown]
# **Optuna ConvNet**

# %%
model = ConvNet(input_size=768)

# %%
# 1 for testing, use at least 20-50 trials.
study, best = training_pipeline.optimize_hyperparameters(model, n_trials=5)
# Out:
# [I 2025-04-17 19:44:24,226] A new study created in memory with name: no-name-566674ad-be77-433e-a4a4-9e39122d6e1b
# Using device: cpu.
#   0%|          | 0/5 [00:00<?, ?it/s]
# -- Trial number 0 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss     dur
# -------  -----------  ------------  -----------  ------------  ------
#       1       0.7214        0.5199       0.7212        0.5193  7.7959
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7214        0.5199       0.7212        0.5193  5.4555
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7214        0.5199       0.7212        0.5193  5.5319
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7214        0.5199       0.7212        0.5193  5.9597
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7214        0.5199       0.7212        0.5193  5.6917
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7214        0.5199       0.7212        0.5193  5.5445
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7214        0.5199       0.7212        0.5193  5.4269
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7214        0.5199       0.7212        0.5193  5.6015
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7214        0.5199       0.7212        0.5193  5.9420
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7214        0.5199       0.7212        0.5193  5.3934
# [I 2025-04-17 19:45:43,943] Trial 0 finished with values: [0.7212040127586095, 0.00020856210901587513] and parameters: {'learning_rate': 1e-05}.
# -- Trial number 1 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss      dur
# -------  -----------  ------------  -----------  ------------  -------
#       1       0.7202        0.5207       0.7166        0.5206  -3.3384
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7201        0.5207       0.7166        0.5206  5.4531
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7201        0.5207       0.7166        0.5206  5.5268
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7201        0.5207       0.7166        0.5206  14.3704
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7201        0.5207       0.7166        0.5206  5.4427
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7201        0.5207       0.7166        0.5206  -3.0644
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7201        0.5207       0.7166        0.5206  5.6721
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7201        0.5207       0.7166        0.5206  5.7764
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7201        0.5207       0.7166        0.5206  6.0491
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7201        0.5207       0.7166        0.5206  6.1188
# [I 2025-04-17 19:46:43,901] Trial 1 finished with values: [0.7165977658545167, 0.0034768847632314914] and parameters: {'learning_rate': 0.1}.
# -- Trial number 2 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss     dur
# -------  -----------  ------------  -----------  ------------  ------
#       1       0.7174        0.5211       0.7166        0.5206  5.4342
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7174        0.5211       0.7166        0.5205  -3.3256
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7174        0.5211       0.7166        0.5205  5.5550
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7174        0.5211       0.7166        0.5205  6.0333
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7174        0.5211       0.7166        0.5205  5.7820
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7174        0.5211       0.7166        0.5205  5.2556
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7174        0.5211       0.7166        0.5205  5.2613
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7174        0.5211       0.7166        0.5205  5.6050
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7174        0.5211       0.7166        0.5205  5.6204
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7174        0.5211       0.7166        0.5205  5.4044
# [I 2025-04-17 19:47:50,781] Trial 2 finished with values: [0.7165977658545167, 0.0008322853592790391] and parameters: {'learning_rate': 1e-06}.
# -- Trial number 3 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss      dur
# -------  -----------  ------------  -----------  ------------  -------
#       1       0.7180        0.5208       0.7179        0.5200  14.1933
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7184        0.5204       0.7179        0.5197  5.2693
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7191        0.5202       0.7212        0.5195  5.5820
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7214        0.5201       0.7212        0.5194  -3.2000
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7214        0.5200       0.7212        0.5194  5.4290
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7214        0.5199       0.7212        0.5193  5.6130
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7214        0.5199       0.7212        0.5193  5.5867
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7214        0.5199       0.7212        0.5193  5.8151
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7214        0.5199       0.7212        0.5193  5.4671
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7214        0.5199       0.7212        0.5193  -3.3693
# [I 2025-04-17 19:48:57,058] Trial 3 finished with values: [0.7212040127586095, 0.00020856210901587513] and parameters: {'learning_rate': 0.0001}.
# -- Trial number 4 --
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss     dur
# -------  -----------  ------------  -----------  ------------  ------
#       1       0.7214        0.5199       0.7212        0.5193  5.4621
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7214        0.5199       0.7212        0.5193  5.5559
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7214        0.5199       0.7212        0.5193  5.4129
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7214        0.5199       0.7212        0.5193  5.6164
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7214        0.5199       0.7212        0.5193  5.5842
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7214        0.5199       0.7212        0.5193  5.8388
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7214        0.5199       0.7212        0.5193  5.5173
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7214        0.5199       0.7212        0.5193  5.1721
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7214        0.5199       0.7212        0.5193  5.1053
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7214        0.5199       0.7212        0.5193  5.2472
# [I 2025-04-17 19:50:11,759] Trial 4 finished with values: [0.7212040127586095, 0.00020856210901587513] and parameters: {'learning_rate': 1e-05}.
# Best trial:
#
# Best trial
#  - Validation accuracy: 0.7212040127586095
#  - Generalization gap: 0.00020856210901587513
# Parameters:
# learning_rate: 1e-05
