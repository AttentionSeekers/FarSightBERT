# %% [markdown]
# Restarted .venv (Python 3.10.16)

# %%
from sentence_transformers import SentenceTransformer, models
import torch

word_embedding_model = models.Transformer(
    'emilyalsentzer/Bio_ClinicalBERT',
    max_seq_length=512,
    model_args={"torch_dtype": torch.float32} 
)

pooling_model = models.Pooling(
    word_embedding_model.get_word_embedding_dimension(),
    pooling_mode_cls_token=True,
    pooling_mode_mean_tokens=False,
    pooling_mode_max_tokens=False
)

model = SentenceTransformer(modules=[word_embedding_model, pooling_model], device='mps')

# %%
import os
os.chdir('../..')

# %%
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': True, 'pooling_mode_mean_tokens': False, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
# )

# %%
import pandas as pd

# %%
df = pd.read_pickle('data/preprocess_clean_remove_rare.pkl')

# %%
df.head(2)
# Out:
#    Unnamed: 0  ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE            CHARTTIME  \
# 0           0  316398       31608  152365.0  2133-01-19  2133-01-19 06:53:00
# 1           1  315910       31608  152365.0  2133-01-13  2133-01-13 06:21:00
#
#              STORETIME CATEGORY            DESCRIPTION     CGID  ISERROR  \
# 0  2133-01-19 06:53:16  Nursing  Nursing Progress Note  19650.0      NaN
# 1  2133-01-13 06:21:26  Nursing  Nursing Progress Note  21198.0      NaN
#
#                                                 TEXT  \
# 0  TITLE:\n   Respiratory failure, acute (not ARD...
# 1  Ineffective Coping\n   Assessment:\n   Pt is n...
#
#                                                PTEXT  \
# 0  [titl, respiratori, failur, acut, doctor, last...
# 1  [ineffect, cope, assess, pt, dnr, pt, ask, res...
#
#                                                FTEXT
# 0  [titl, respiratori, failur, acut, doctor, last...
# 1  [ineffect, cope, assess, pt, dnr, pt, ask, res...

# %%
df['SENT'] = df['FTEXT'].apply(lambda tokens: ' '.join(tokens))

# %%
df.head(2)
# Out:
#    Unnamed: 0  ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE            CHARTTIME  \
# 0           0  316398       31608  152365.0  2133-01-19  2133-01-19 06:53:00
# 1           1  315910       31608  152365.0  2133-01-13  2133-01-13 06:21:00
#
#              STORETIME CATEGORY            DESCRIPTION     CGID  ISERROR  \
# 0  2133-01-19 06:53:16  Nursing  Nursing Progress Note  19650.0      NaN
# 1  2133-01-13 06:21:26  Nursing  Nursing Progress Note  21198.0      NaN
#
#                                                 TEXT  \
# 0  TITLE:\n   Respiratory failure, acute (not ARD...
# 1  Ineffective Coping\n   Assessment:\n   Pt is n...
#
#                                                PTEXT  \
# 0  [titl, respiratori, failur, acut, doctor, last...
# 1  [ineffect, cope, assess, pt, dnr, pt, ask, res...
#
#                                                FTEXT  \
# 0  [titl, respiratori, failur, acut, doctor, last...
# 1  [ineffect, cope, assess, pt, dnr, pt, ask, res...
#
#                                                 SENT
# 0  titl respiratori failur acut doctor last name ...
# 1  ineffect cope assess pt dnr pt ask resp tech c...

# %%
df['SENT'][5]
# Out:
# 'respiratori failur acut doctor last name assess action respons plan ineffect cope assess action respons plan'

# %%
sentences = df['SENT'].tolist()

# %%
df.shape
# Out:
# (142110, 15)

# %%
len(sentences)
# Out:
# 142110

# %%
embeddings = model.encode(sentences, batch_size=16, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/8882 [00:00<?, ?it/s]

# %%
import pickle

with open("embeddings.pkl", "wb") as f:
    pickle.dump(embeddings, f)

# %%
type(embeddings)
# Out:
# numpy.ndarray

# %%
embeddings
# Out:
# array([[-0.03600806, -0.05763245, -0.5764836 , ...,  0.05967164,
#         -0.06377713, -0.15175182],
#        [ 0.04741407, -0.25133044, -0.42309144, ...,  0.02087078,
#          0.12380733, -0.0428645 ],
#        [ 0.0549481 ,  0.30195963, -0.5842947 , ..., -0.05654861,
#          0.12264945, -0.35312414],
#        ...,
#        [ 0.01555623,  0.24602246, -0.39466158, ..., -0.06074153,
#         -0.00849961, -0.11809866],
#        [ 0.07003576, -0.01468849, -0.46918246, ...,  0.03723217,
#          0.13071527, -0.04235954],
#        [ 0.06021408,  0.03543237, -0.64930576, ...,  0.24909644,
#          0.01986872, -0.04088048]], dtype=float32)

# %%
df['EMBEDDING'] = list(embeddings)

# %%
df.head()
# Out:
#    Unnamed: 0  ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE            CHARTTIME  \
# 0           0  316398       31608  152365.0  2133-01-19  2133-01-19 06:53:00
# 1           1  315910       31608  152365.0  2133-01-13  2133-01-13 06:21:00
# 2           2  316202       31608  152365.0  2133-01-16  2133-01-16 03:53:00
# 3           3  316288       31608  152365.0  2133-01-17  2133-01-17 15:10:00
# 4           5  316296       31608  152365.0  2133-01-17  2133-01-17 15:10:00
#
#              STORETIME CATEGORY            DESCRIPTION     CGID  ISERROR  \
# 0  2133-01-19 06:53:16  Nursing  Nursing Progress Note  19650.0      NaN
# 1  2133-01-13 06:21:26  Nursing  Nursing Progress Note  21198.0      NaN
# 2  2133-01-16 03:53:57  Nursing  Nursing Progress Note  14442.0      NaN
# 3  2133-01-17 15:10:44  Nursing  Nursing Progress Note  15065.0      NaN
# 4  2133-01-17 18:08:06  Nursing  Nursing Progress Note  15065.0      NaN
#
#                                                 TEXT  \
# 0  TITLE:\n   Respiratory failure, acute (not ARD...
# 1  Ineffective Coping\n   Assessment:\n   Pt is n...
# 2  Respiratory failure, acute (not ARDS/[**Doctor...
# 3  Respiratory failure, acute (not ARDS/[**Doctor...
# 4  Respiratory failure, acute (not ARDS/[**Doctor...
#
#                                                PTEXT  \
# 0  [titl, respiratori, failur, acut, doctor, last...
# 1  [ineffect, cope, assess, pt, dnr, pt, ask, res...
# 2  [respiratori, failur, acut, doctor, last, name...
# 3  [respiratori, failur, acut, doctor, last, name...
# 4  [respiratori, failur, acut, doctor, last, name...
#
#                                                FTEXT  \
# 0  [titl, respiratori, failur, acut, doctor, last...
# 1  [ineffect, cope, assess, pt, dnr, pt, ask, res...
# 2  [respiratori, failur, acut, doctor, last, name...
# 3  [respiratori, failur, acut, doctor, last, name...
# 4  [respiratori, failur, acut, doctor, last, name...
#
#                                                 SENT  \
# 0  titl respiratori failur acut doctor last name ...
# 1  ineffect cope assess pt dnr pt ask resp tech c...
# 2  respiratori failur acut doctor last name asses...
# 3  respiratori failur acut doctor last name asses...
# 4  respiratori failur acut doctor last name asses...
#
#                                            EMBEDDING
# 0  [-0.036008064, -0.057632454, -0.5764836, 0.473...
# 1  [0.04741407, -0.25133044, -0.42309144, 0.49156...
# 2  [0.054948103, 0.30195963, -0.5842947, 0.443203...
# 3  [0.14360966, -0.1609861, -0.49888694, 0.472669...
# 4  [0.14360966, -0.1609861, -0.49888694, 0.472669...

# %%
df.to_pickle('data/notes_with_embeddings.pkl')
