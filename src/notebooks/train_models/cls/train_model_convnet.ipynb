# %%
import os
os.chdir('../../..')
print(os.getcwd())
# Out:
# /Users/nkapila6/Code/nlpvise/src

# %%
from training_pipeline import TrainingPipeline
from models.convnet import ConvNet

# %%
MAX_EPOCHS = 30
RANDOM_STATE = 42

# %%
training_pipeline = TrainingPipeline()

# %% [markdown]
# **Load the data and split train test set**

# %%
training_pipeline.load_data()
# Out:
# Data loaded successfully.
# Train/Test split completed.

# %% [markdown]
# **Train ConvNet**

# %%
model = ConvNet(input_size=768)

# %%
# Learning rate identified using Optuna
args = { 'max_epochs': 10,
         'learning_rate': 1e-03,
         'random_state': RANDOM_STATE,
         'batch_size': 128,
        }
training_pipeline.train_model(model, args=args)
# Out:
# Using device: mps
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss      dur
# -------  -----------  ------------  -------
#       1       0.7624        0.4790  10.5306
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7735        0.4629  7.8282
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7772        0.4569  8.2001
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7798        0.4527  7.9463
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7818        0.4494  8.1256
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7838        0.4463  8.0509
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7853        0.4437  8.4761
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7866        0.4413  8.0615
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7879        0.4391  8.1770
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7891        0.4372  8.0076
