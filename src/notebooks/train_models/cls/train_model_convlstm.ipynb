# %%
import os
os.chdir('../../..')
print(os.getcwd())
# Out:
# /teamspace/studios/this_studio/nlpvise/src

# %%
from training_pipeline import TrainingPipeline
from models.convlstm import ConvLSTM

# %%
MAX_EPOCHS = 30
RANDOM_STATE = 42

# %%
training_pipeline = TrainingPipeline()

# %% [markdown]
# **Load the data and split train test set**

# %%
training_pipeline.load_data()
# Out:
# Data loaded successfully.
# Train/Test split completed.

# %% [markdown]
# **Train ConvNet**

# %%
model = ConvLSTM(input_size=768)

# %%
# Learning rate identified using Optuna
args = { 'max_epochs': MAX_EPOCHS,
         'learning_rate': 0.001,
         'random_state': RANDOM_STATE,
         'batch_size': 128,
        }
training_pipeline.train_model(model, args=args)
# Out:
# Using device: cuda
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss     dur
# -------  -----------  ------------  ------
#       1       0.7464        0.4988  7.9493
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7644        0.4765  7.3059
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7715        0.4659  7.0874
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7761        0.4587  7.4439
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7794        0.4535  7.4088
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7824        0.4488  7.1640
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7847        0.4446  7.5454
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7872        0.4403  7.2650
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7897        0.4362  7.1055
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7921        0.4323  7.1765
#   0%|          | 0/889 [00:00<?, ?it/s]
#      11       0.7942        0.4287  7.7464
#   0%|          | 0/889 [00:00<?, ?it/s]
#      12       0.7963        0.4254  10.1741
#   0%|          | 0/889 [00:00<?, ?it/s]
#      13       0.7984        0.4220  10.3563
#   0%|          | 0/889 [00:00<?, ?it/s]
#      14       0.8002        0.4186  10.5847
#   0%|          | 0/889 [00:00<?, ?it/s]
#      15       0.8020        0.4154  10.8039
#   0%|          | 0/889 [00:00<?, ?it/s]
#      16       0.8034        0.4128  11.1044
#   0%|          | 0/889 [00:00<?, ?it/s]
#      17       0.8048        0.4103  11.1209
#   0%|          | 0/889 [00:00<?, ?it/s]
#      18       0.8069        0.4070  11.2937
#   0%|          | 0/889 [00:00<?, ?it/s]
#      19       0.8082        0.4046  11.3420
#   0%|          | 0/889 [00:00<?, ?it/s]
#      20       0.8104        0.4010  11.0337
#   0%|          | 0/889 [00:00<?, ?it/s]
#      21       0.8117        0.3986  10.5260
#   0%|          | 0/889 [00:00<?, ?it/s]
#      22       0.8136        0.3959  10.1342
#   0%|          | 0/889 [00:00<?, ?it/s]
#      23       0.8155        0.3925  9.3770
#   0%|          | 0/889 [00:00<?, ?it/s]
#      24       0.8166        0.3908  9.4048
#   0%|          | 0/889 [00:00<?, ?it/s]
#      25       0.8175        0.3888  9.3683
#   0%|          | 0/889 [00:00<?, ?it/s]
#      26       0.8185        0.3872  9.1608
#   0%|          | 0/889 [00:00<?, ?it/s]
#      27       0.8198        0.3847  9.4611
#   0%|          | 0/889 [00:00<?, ?it/s]
#      28       0.8208        0.3830  9.6640
#   0%|          | 0/889 [00:00<?, ?it/s]
#      29       0.8225        0.3802  10.1770
#   0%|          | 0/889 [00:00<?, ?it/s]
#      30       0.8238        0.3778  10.5702
