# %%
import os
os.chdir('../../..')
print(os.getcwd())
# Out:
# /Users/nkapila6/Code/nlpvise/src

# %%
from training_pipeline import TrainingPipeline
from models.convnet import ConvNet

# %%
MAX_EPOCHS = 8
RANDOM_STATE = 42

# %%
training_pipeline = TrainingPipeline()
training_pipeline.CLS = False

# %% [markdown]
# **Load the data and split train test set**

# %%
training_pipeline.load_data()
# Out:
# Loading mean embeddings. CLS is False.
# Data loaded successfully.
# Train/Test split completed.

# %% [markdown]
# **Train ConvNet**

# %%
model = ConvNet(input_size=768)

# %%
# Learning rate identified using Optuna
args = { 'max_epochs': MAX_EPOCHS,
         'learning_rate': 1e-3,
         'random_state': RANDOM_STATE,
         'batch_size': 128,
        }
training_pipeline.train_model(model, args=args)
# Out:
# Using device: mps
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss      dur
# -------  -----------  ------------  -------
#       1       0.7656        0.4744  11.7040
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7782        0.4556  7.5898
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7818        0.4495  10.4425
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7841        0.4456  10.4082
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7858        0.4426  6.9314
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7870        0.4404  10.0555
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7881        0.4384  9.7911
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7894        0.4365  7.2120
#
# Saving model at trained_models/mean_embeddings/ConvNet_MEAN.pkl
