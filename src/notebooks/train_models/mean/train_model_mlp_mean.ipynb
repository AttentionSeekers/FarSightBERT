# %%
import os
os.chdir('../../..')
print(os.getcwd())
# Out:
# /Users/nkapila6/Code/nlpvise/src

# %%
from training_pipeline import TrainingPipeline
from models.mlp import mlp

# %%
MAX_EPOCHS = 8
RANDOM_STATE = 42

# %%
training_pipeline = TrainingPipeline()
training_pipeline.CLS = False

# %% [markdown]
# **Load the data and split train test set**

# %%
training_pipeline.load_data()
# Out:
# Loading mean embeddings. CLS is False.
# Data loaded successfully.
# Train/Test split completed.

# %% [markdown]
# **Train ConvNet**

# %%
model = mlp(input_size=768)

# %%
# Learning rate identified using Optuna
args = { 'max_epochs': MAX_EPOCHS,
         'learning_rate': 1e-3,
         'random_state': RANDOM_STATE,
         'batch_size': 128,
        }
training_pipeline.train_model(model, args=args)
# Out:
# Using device: mps
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss     dur
# -------  -----------  ------------  ------
#       1       0.7600        0.4839  8.9101
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7730        0.4654  6.3738
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7763        0.4600  5.8773
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7782        0.4566  7.2876
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7796        0.4540  7.6343
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7807        0.4520  5.8716
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7817        0.4503  6.1759
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7826        0.4488  7.7255
#
# Saving model at trained_models/mean_embeddings/mlp_MEAN.pkl
