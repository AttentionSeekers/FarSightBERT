# %%
import os
os.chdir('../..')
print(os.getcwd())
# Out:
# /home/trath/Code/nlpvise/src

# %%
from training_pipeline import TrainingPipeline
from models.convlstm import ConvLSTM

# %%
MAX_EPOCHS = 10
RANDOM_STATE = 42

# %%
training_pipeline = TrainingPipeline()

# %% [markdown]
# **Load the data and split train test set**

# %%
training_pipeline.load_data()
# Out:
# Data loaded successfully.
# Train/Test split completed.

# %% [markdown]
# **Train ConvNet**

# %%
model = ConvLSTM(input_size=768)

# %%
args = { 'max_epochs': MAX_EPOCHS,
         'learning_rate': 0.001,
         'random_state': RANDOM_STATE,
         'batch_size': 128,
        }
training_pipeline.train_model(model, args=args)
# Out:
# Using device: cpu
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss      dur
# -------  -----------  ------------  -----------  ------------  -------
#       1       0.7461        0.4995       0.7607        0.4845  20.6258
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7636        0.4787       0.7658        0.4735  28.4209
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7693        0.4695       0.7733        0.4642  29.9548
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7739        0.4626       0.7749        0.4600  29.8527
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7772        0.4574       0.7763        0.4572  30.5523
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7802        0.4526       0.7766        0.4573  29.5275
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7828        0.4483       0.7772        0.4562  31.7822
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7852        0.4444       0.7783        0.4539  22.9680
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7875        0.4407       0.7790        0.4544  31.3999
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7897        0.4371       0.7804        0.4517  44.9854
