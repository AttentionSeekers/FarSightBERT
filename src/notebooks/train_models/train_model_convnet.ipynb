# %%
import os
os.chdir('../..')
print(os.getcwd())
# Out:
# /home/trath/Code/nlpvise/src

# %%
from training_pipeline import TrainingPipeline
from models.convnet import ConvNet

# %%
MAX_EPOCHS = 30
RANDOM_STATE = 42

# %%
training_pipeline = TrainingPipeline()

# %% [markdown]
# **Load the data and split train test set**

# %%
training_pipeline.load_data()
# Out:
# Data loaded successfully.
# Train/Test split completed.

# %% [markdown]
# **Train ConvNet**

# %%
model = ConvNet(input_size=768)

# %%
args = { 'max_epochs': MAX_EPOCHS,
         'learning_rate': 1e-05,
         'random_state': RANDOM_STATE,
         'batch_size': 128,
        }
training_pipeline.train_model(model, args=args)
# Out:
# Using device: cpu
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss     dur
# -------  -----------  ------------  -----------  ------------  ------
#       1       0.7162        0.5547       0.7273        0.5168  5.8655
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7347        0.5119       0.7399        0.5063  6.0185
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7425        0.5033       0.7453        0.5002  5.7786
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7473        0.4985       0.7496        0.4962  5.9969
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7511        0.4948       0.7528        0.4928  6.2155
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7542        0.4917       0.7556        0.4899  6.2367
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7567        0.4891       0.7582        0.4875  5.8327
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7587        0.4869       0.7596        0.4855  -2.7075
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7601        0.4851       0.7609        0.4839  5.8738
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7613        0.4835       0.7620        0.4824  14.4995
#   0%|          | 0/889 [00:00<?, ?it/s]
#      11       0.7623        0.4822       0.7630        0.4812  5.9161
#   0%|          | 0/889 [00:00<?, ?it/s]
#      12       0.7631        0.4810       0.7638        0.4801  5.6297
#   0%|          | 0/889 [00:00<?, ?it/s]
#      13       0.7636        0.4800       0.7643        0.4791  -3.0756
#   0%|          | 0/889 [00:00<?, ?it/s]
#      14       0.7642        0.4790       0.7649        0.4782  6.1205
#   0%|          | 0/889 [00:00<?, ?it/s]
#      15       0.7647        0.4781       0.7655        0.4774  5.5750
#   0%|          | 0/889 [00:00<?, ?it/s]
#      16       0.7652        0.4773       0.7658        0.4766  5.9898
#   0%|          | 0/889 [00:00<?, ?it/s]
#      17       0.7657        0.4765       0.7662        0.4758  14.7773
#   0%|          | 0/889 [00:00<?, ?it/s]
#      18       0.7662        0.4758       0.7667        0.4751  5.9098
#   0%|          | 0/889 [00:00<?, ?it/s]
#      19       0.7665        0.4751       0.7672        0.4745  -2.7815
#   0%|          | 0/889 [00:00<?, ?it/s]
#      20       0.7670        0.4745       0.7676        0.4738  5.8712
#   0%|          | 0/889 [00:00<?, ?it/s]
#      21       0.7674        0.4738       0.7679        0.4732  6.0859
#   0%|          | 0/889 [00:00<?, ?it/s]
#      22       0.7678        0.4732       0.7683        0.4727  5.5441
#   0%|          | 0/889 [00:00<?, ?it/s]
#      23       0.7681        0.4727       0.7686        0.4721  5.9999
#   0%|          | 0/889 [00:00<?, ?it/s]
#      24       0.7685        0.4721       0.7690        0.4716  5.7059
#   0%|          | 0/889 [00:00<?, ?it/s]
#      25       0.7688        0.4716       0.7693        0.4711  5.6806
#   0%|          | 0/889 [00:00<?, ?it/s]
#      26       0.7691        0.4711       0.7695        0.4706  5.9081
#   0%|          | 0/889 [00:00<?, ?it/s]
#      27       0.7694        0.4706       0.7698        0.4702  5.6557
#   0%|          | 0/889 [00:00<?, ?it/s]
#      28       0.7697        0.4701       0.7701        0.4697  5.7451
#   0%|          | 0/889 [00:00<?, ?it/s]
#      29       0.7701        0.4696       0.7703        0.4693  5.5662
#   0%|          | 0/889 [00:00<?, ?it/s]
#      30       0.7703        0.4692       0.7706        0.4689  5.5285
