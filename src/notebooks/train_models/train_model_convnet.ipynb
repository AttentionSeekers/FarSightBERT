# %%
import os
os.chdir('../..')
print(os.getcwd())
# Out:
# /teamspace/studios/this_studio/nlpvise/src

# %%
from training_pipeline import TrainingPipeline
from models.convnet import ConvNet

# %%
MAX_EPOCHS = 30
RANDOM_STATE = 42

# %%
training_pipeline = TrainingPipeline()

# %% [markdown]
# **Load the data and split train test set**

# %%
training_pipeline.load_data()
# Out:
# Data loaded successfully.
# Train/Test split completed.

# %% [markdown]
# **Train ConvNet**

# %%
model = ConvNet(input_size=768)

# %%
# Learning rate identified using Optuna
args = { 'max_epochs': MAX_EPOCHS,
         'learning_rate': 1e-05,
         'random_state': RANDOM_STATE,
         'batch_size': 128,
        }
training_pipeline.train_model(model, args=args)
# Out:
# Using device: cuda
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss     dur
# -------  -----------  ------------  ------
#       1       0.7230        0.5359  4.2112
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7407        0.5055  4.4507
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7482        0.4978  3.5346
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7532        0.4927  3.5201
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7568        0.4888  3.4963
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7594        0.4859  3.0942
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7611        0.4836  3.9150
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7625        0.4818  4.2099
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7634        0.4803  3.5835
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7642        0.4790  3.5198
#   0%|          | 0/889 [00:00<?, ?it/s]
#      11       0.7649        0.4779  3.6455
#   0%|          | 0/889 [00:00<?, ?it/s]
#      12       0.7655        0.4769  3.6436
#   0%|          | 0/889 [00:00<?, ?it/s]
#      13       0.7660        0.4760  3.3734
#   0%|          | 0/889 [00:00<?, ?it/s]
#      14       0.7666        0.4751  4.6309
#   0%|          | 0/889 [00:00<?, ?it/s]
#      15       0.7671        0.4743  3.7436
#   0%|          | 0/889 [00:00<?, ?it/s]
#      16       0.7676        0.4736  3.7640
#   0%|          | 0/889 [00:00<?, ?it/s]
#      17       0.7681        0.4728  4.5239
#   0%|          | 0/889 [00:00<?, ?it/s]
#      18       0.7685        0.4722  3.8089
#   0%|          | 0/889 [00:00<?, ?it/s]
#      19       0.7690        0.4715  4.2205
#   0%|          | 0/889 [00:00<?, ?it/s]
#      20       0.7694        0.4709  4.1365
#   0%|          | 0/889 [00:00<?, ?it/s]
#      21       0.7697        0.4703  3.9390
#   0%|          | 0/889 [00:00<?, ?it/s]
#      22       0.7701        0.4698  4.0090
#   0%|          | 0/889 [00:00<?, ?it/s]
#      23       0.7705        0.4692  4.6206
#   0%|          | 0/889 [00:00<?, ?it/s]
#      24       0.7708        0.4687  3.4655
#   0%|          | 0/889 [00:00<?, ?it/s]
#      25       0.7711        0.4682  4.3874
#   0%|          | 0/889 [00:00<?, ?it/s]
#      26       0.7714        0.4677  4.0120
#   0%|          | 0/889 [00:00<?, ?it/s]
#      27       0.7717        0.4673  3.5583
#   0%|          | 0/889 [00:00<?, ?it/s]
#      28       0.7720        0.4668  4.5207
#   0%|          | 0/889 [00:00<?, ?it/s]
#      29       0.7723        0.4664  3.2412
#   0%|          | 0/889 [00:00<?, ?it/s]
#      30       0.7725        0.4660  4.6328
