# %%
import os
os.chdir('../..')
print(os.getcwd())
# Out:
# /home/trath/Code/nlpvise/src

# %%
from training_pipeline import TrainingPipeline
from models.convnet import ConvNet

# %%
MAX_EPOCHS = 20
RANDOM_STATE = 42

# %%
training_pipeline = TrainingPipeline()

# %% [markdown]
# **Load the data and split train test set**

# %%
training_pipeline.load_data()
# Out:
# Data loaded successfully.
# Train/Test split completed.

# %% [markdown]
# **Train ConvNet**

# %%
model = ConvNet(input_size=768)

# %%
args = { 'max_epochs': MAX_EPOCHS,
         'learning_rate': 1e-05,
         'random_state': RANDOM_STATE,
         'batch_size': 128,
        }
training_pipeline.train_model(model, args=args)
# Out:
# Using device: cpu
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss    valid_acc    valid_loss     dur
# -------  -----------  ------------  -----------  ------------  ------
#       1       0.7609        0.4839       0.7616        0.4829  6.1205
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7618        0.4828       0.7623        0.4818  6.4137
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7625        0.4817       0.7630        0.4808  5.5170
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7632        0.4807       0.7637        0.4799  5.2635
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7638        0.4798       0.7642        0.4790  5.7911
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7642        0.4790       0.7647        0.4782  5.4708
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7647        0.4782       0.7651        0.4775  5.8639
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7651        0.4775       0.7656        0.4768  5.4877
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7655        0.4768       0.7661        0.4761  5.5458
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7659        0.4761       0.7665        0.4755  5.2227
#   0%|          | 0/889 [00:00<?, ?it/s]
#      11       0.7663        0.4755       0.7667        0.4749  5.5113
#   0%|          | 0/889 [00:00<?, ?it/s]
#      12       0.7666        0.4749       0.7672        0.4743  5.5988
#   0%|          | 0/889 [00:00<?, ?it/s]
#      13       0.7670        0.4743       0.7677        0.4737  14.1132
#   0%|          | 0/889 [00:00<?, ?it/s]
#      14       0.7673        0.4738       0.7679        0.4732  5.9102
#   0%|          | 0/889 [00:00<?, ?it/s]
#      15       0.7676        0.4732       0.7682        0.4727  5.7409
#   0%|          | 0/889 [00:00<?, ?it/s]
#      16       0.7680        0.4727       0.7686        0.4722  5.6362
#   0%|          | 0/889 [00:00<?, ?it/s]
#      17       0.7683        0.4722       0.7688        0.4718  5.4421
#   0%|          | 0/889 [00:00<?, ?it/s]
#      18       0.7687        0.4718       0.7691        0.4713  5.1488
#   0%|          | 0/889 [00:00<?, ?it/s]
#      19       0.7690        0.4713       0.7693        0.4709  13.9289
#   0%|          | 0/889 [00:00<?, ?it/s]
#      20       0.7693        0.4709       0.7696        0.4705  5.4080
