# %%
import os
os.chdir('../..')
print(os.getcwd())
# Out:
# /teamspace/studios/this_studio/nlpvise/src

# %%
from training_pipeline import TrainingPipeline
from models.bilstm import BiLSTM

# %%
MAX_EPOCHS = 30
RANDOM_STATE = 42

# %%
training_pipeline = TrainingPipeline()

# %% [markdown]
# **Load the data and split train test set**

# %%
training_pipeline.load_data()
# Out:
# Data loaded successfully.
# Train/Test split completed.

# %% [markdown]
# **Train ConvNet**

# %%
model = BiLSTM(input_size=768)

# %%
# Learning rate identified using Optuna
args = { 'max_epochs': MAX_EPOCHS,
         'learning_rate': 1e-5,
         'random_state': RANDOM_STATE,
         'batch_size': 128,
        }
training_pipeline.train_model(model, args=args)
# Out:
# Using device: cuda
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_acc    train_loss      dur
# -------  -----------  ------------  -------
#       1       0.7166        0.5445  11.7360
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2       0.7292        0.5163  11.4809
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3       0.7395        0.5072  11.4969
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4       0.7445        0.5014  11.6438
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5       0.7477        0.4979  11.8573
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6       0.7506        0.4951  11.8157
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7       0.7530        0.4928  11.8999
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8       0.7554        0.4907  11.8040
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9       0.7572        0.4889  11.6129
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10       0.7586        0.4873  11.4179
#   0%|          | 0/889 [00:00<?, ?it/s]
#      11       0.7597        0.4859  11.1664
#   0%|          | 0/889 [00:00<?, ?it/s]
#      12       0.7606        0.4845  11.0076
#   0%|          | 0/889 [00:00<?, ?it/s]
#      13       0.7615        0.4834  11.8857
#   0%|          | 0/889 [00:00<?, ?it/s]
#      14       0.7623        0.4823  11.4325
#   0%|          | 0/889 [00:00<?, ?it/s]
#      15       0.7628        0.4814  10.6534
#   0%|          | 0/889 [00:00<?, ?it/s]
#      16       0.7634        0.4805  11.0375
#   0%|          | 0/889 [00:00<?, ?it/s]
#      17       0.7640        0.4797  11.2440
#   0%|          | 0/889 [00:00<?, ?it/s]
#      18       0.7644        0.4789  11.4744
#   0%|          | 0/889 [00:00<?, ?it/s]
#      19       0.7648        0.4782  9.5480
#   0%|          | 0/889 [00:00<?, ?it/s]
#      20       0.7652        0.4776  9.3284
#   0%|          | 0/889 [00:00<?, ?it/s]
#      21       0.7655        0.4769  9.3673
#   0%|          | 0/889 [00:00<?, ?it/s]
#      22       0.7660        0.4763  9.1879
#   0%|          | 0/889 [00:00<?, ?it/s]
#      23       0.7663        0.4757  9.2792
#   0%|          | 0/889 [00:00<?, ?it/s]
#      24       0.7667        0.4751  9.1221
#   0%|          | 0/889 [00:00<?, ?it/s]
#      25       0.7671        0.4746  9.2523
#   0%|          | 0/889 [00:00<?, ?it/s]
#      26       0.7674        0.4741  9.3020
#   0%|          | 0/889 [00:00<?, ?it/s]
#      27       0.7678        0.4735  9.2752
#   0%|          | 0/889 [00:00<?, ?it/s]
#      28       0.7681        0.4730  9.2160
#   0%|          | 0/889 [00:00<?, ?it/s]
#      29       0.7684        0.4726  9.2421
#   0%|          | 0/889 [00:00<?, ?it/s]
#      30       0.7687        0.4721  8.9395
