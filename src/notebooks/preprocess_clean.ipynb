# %%
import os
print(os.getcwd())
os.chdir('..')
print(os.getcwd())
# Out:
# /Users/nkapila6/Code/nlpvise/src/notebooks
# /Users/nkapila6/Code/nlpvise/src

# %%
# !python data_pipeline.py --name preprocess
# Out:
# Step 4.0: Downloading necessary resources.
# [nltk_data] Downloading package punkt to /Users/nkapila6/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nkapila6/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/nkapila6/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#
# Step 4.1: Preprocessing and Cleaning Text.
#
# Saving to data/preprocess_clean_notes.pkl
#
# Step 4.2: Remove rare tokens (<10).
#
# Saving to data/preprocess_clean_remove_rare.pkl

# %%
import pandas as pd
notes = pd.read_pickle('data/preprocess_clean_remove_rars.pkl')
notes.head(3)
# Out:
#    Unnamed: 0  ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE            CHARTTIME  \
# 0           0  316398       31608  152365.0  2133-01-19  2133-01-19 06:53:00
# 1           1  315910       31608  152365.0  2133-01-13  2133-01-13 06:21:00
# 2           2  316202       31608  152365.0  2133-01-16  2133-01-16 03:53:00
#
#              STORETIME CATEGORY            DESCRIPTION     CGID  ISERROR  \
# 0  2133-01-19 06:53:16  Nursing  Nursing Progress Note  19650.0      NaN
# 1  2133-01-13 06:21:26  Nursing  Nursing Progress Note  21198.0      NaN
# 2  2133-01-16 03:53:57  Nursing  Nursing Progress Note  14442.0      NaN
#
#                                                 TEXT  \
# 0  TITLE:\n   Respiratory failure, acute (not ARD...
# 1  Ineffective Coping\n   Assessment:\n   Pt is n...
# 2  Respiratory failure, acute (not ARDS/[**Doctor...
#
#                                                PTEXT  \
# 0  [titl, respiratori, failur, acut, doctor, last...
# 1  [ineffect, cope, assess, pt, dnr, pt, ask, res...
# 2  [respiratori, failur, acut, doctor, last, name...
#
#                                                FTEXT
# 0  [titl, respiratori, failur, acut, doctor, last...
# 1  [ineffect, cope, assess, pt, dnr, pt, ask, res...
# 2  [respiratori, failur, acut, doctor, last, name...

# %%
notes['SUBJECT_ID'].nunique()
# Out:
# 6732

# %% [markdown]
# "Additionally, we eliminated the tokens appearing in less than
# ten nursing notes (e.g., spot, cope, and inch) in order to
# lower the computational complexity of training (the total
# number of tokens pre- and post-elimination were 188,742 and 32
# 687 respectively) and mitigate problems arising due to
# overfitting."

# %%
notes['FTEXT'].explode().nunique()
# Out:
# 20951

# %%
print(len(notes['FTEXT'][0]))
# Out:
# 153
