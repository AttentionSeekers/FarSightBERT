# %%
import os
os.chdir('..')
print(os.getcwd())
# Out:
# /home/trath/Code/nlpvise/src

# %%
from training_pipeline import TrainingPipeline
from models.convnet import ConvNet

# %%
MAX_EPOCHS = 10
RANDOM_STATE = 42

# %%
training_pipeline = TrainingPipeline()

# %% [markdown]
# **Load the data and split train test set**

# %%
training_pipeline.load_data()
# Out:
# Data loaded successfully.
# Train Test split generated successfully !

# %% [markdown]
# **Train ConvNet**

# %%
model = ConvNet(input_size=768)
args = { 'max_epochs': MAX_EPOCHS,
         'learning_rate': 0.001,
         'random_state': RANDOM_STATE,
         'batch_size': 128
        }
training_pipeline.train_model(model, args=args)
# Out:
#   0%|          | 0/889 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 7
#       1 model = ConvNet(input_size=768)
#       2 args = { 'max_epochs': MAX_EPOCHS,
#       3          'learning_rate': 0.001,
#       4          'random_state': RANDOM_STATE,
#       5          'batch_size': 128
#       6         }
# ----> 7 training_pipeline.train_model(model, args=args)
#
# File ~/Code/nlpvise/src/training_pipeline.py:75, in TrainingPipeline.train_model(self, model, args)
#      61 training_acc_callback = EpochScoring(train_acc_scoring, name='train_acc',  on_train=True, lower_is_better=False)
#      63 net = NeuralNetClassifier(
#      64         model,
#      65         max_epochs=max_epochs,
#    (...)
#      72         device=self.device
#      73     )
# ---> 75 net.fit(X=self.X_train, y=self.y_train)
#      77 # Save trained model to use it later in mixture of model architecture
#      78 with open(f'trained_models/{type(model).__name__}.pkl', 'wb') as f:
#
# File ~/Code/nlpvise/.venv/lib/python3.10/site-packages/skorch/classifier.py:165, in NeuralNetClassifier.fit(self, X, y, **fit_params)
#     154 """See ``NeuralNet.fit``.
#     155
#     156 In contrast to ``NeuralNet.fit``, ``y`` is non-optional to
#    (...)
#     160
#     161 """
#     162 # pylint: disable=useless-super-delegation
#     163 # this is actually a pylint bug:
#     164 # https://github.com/PyCQA/pylint/issues/1085
# --> 165 return super(NeuralNetClassifier, self).fit(X, y, **fit_params)
#
# File ~/Code/nlpvise/.venv/lib/python3.10/site-packages/skorch/net.py:1349, in NeuralNet.fit(self, X, y, **fit_params)
#    1346 if not self.warm_start or not self.initialized_:
#    1347     self.initialize()
# -> 1349 self.partial_fit(X, y, **fit_params)
#    1350 return self
#
# File ~/Code/nlpvise/.venv/lib/python3.10/site-packages/skorch/net.py:1308, in NeuralNet.partial_fit(self, X, y, classes, **fit_params)
#    1306 self.notify('on_train_begin', X=X, y=y)
#    1307 try:
# -> 1308     self.fit_loop(X, y, **fit_params)
#    1309 except KeyboardInterrupt:
#    1310     pass
#
# File ~/Code/nlpvise/.venv/lib/python3.10/site-packages/skorch/net.py:1226, in NeuralNet.fit_loop(self, X, y, epochs, **fit_params)
#    1220     self.run_single_epoch(iterator_train, training=True, prefix="train",
#    1221                           step_fn=self.train_step, **fit_params)
#    1223     self.run_single_epoch(iterator_valid, training=False, prefix="valid",
#    1224                           step_fn=self.validation_step, **fit_params)
# -> 1226     self.notify("on_epoch_end", **on_epoch_kwargs)
#    1227 return self
#
# File ~/Code/nlpvise/.venv/lib/python3.10/site-packages/skorch/net.py:416, in NeuralNet.notify(self, method_name, **cb_kwargs)
#     414 getattr(self, method_name)(self, **cb_kwargs)
#     415 for _, cb in self.callbacks_:
# --> 416     getattr(cb, method_name)(self, **cb_kwargs)
#
# File ~/Code/nlpvise/.venv/lib/python3.10/site-packages/skorch/callbacks/scoring.py:454, in EpochScoring.on_epoch_end(self, net, dataset_train, dataset_valid, **kwargs)
#     451     return
#     453 with _cache_net_forward_iter(net, self.use_caching, y_pred) as cached_net:
# --> 454     current_score = self._scoring(cached_net, X_test, y_test)
#     456 self._record_score(net.history, current_score)
#
# File ~/Code/nlpvise/.venv/lib/python3.10/site-packages/skorch/callbacks/scoring.py:146, in ScoringBase._scoring(self, net, X_test, y_test)
#     143 """Resolve scoring and apply it to data. Use cached prediction
#     144 instead of running inference again, if available."""
#     145 scorer = check_scoring(net, self.scoring_)
# --> 146 return scorer(net, X_test, y_test)
#
# File ~/Code/nlpvise/src/training_pipeline.py:59, in TrainingPipeline.train_model.<locals>.train_acc_scoring(net, batch, y)
#      56     # train_actual = np.array([X.dataset.targets[idx] for idx in X.indices])
#      57 train_preds = net.predict(batch)
# ---> 59 return accuracy_score(train_actual, train_preds)
#
# File ~/Code/nlpvise/.venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File ~/Code/nlpvise/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:227, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     225 # Compute accuracy for each possible representation
#     226 y_true, y_pred = attach_unique(y_true, y_pred)
# --> 227 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     228 check_consistent_length(y_true, y_pred, sample_weight)
#     230 if y_type.startswith("multilabel"):
#
# File ~/Code/nlpvise/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:98, in _check_targets(y_true, y_pred)
#      71 """Check that y_true and y_pred belong to the same classification task.
#      72
#      73 This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      95 y_pred : array or indicator matrix
#      96 """
#      97 xp, _ = get_namespace(y_true, y_pred)
# ---> 98 check_consistent_length(y_true, y_pred)
#      99 type_true = type_of_target(y_true, input_name="y_true")
#     100 type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~/Code/nlpvise/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py:475, in check_consistent_length(*arrays)
#     473 uniques = np.unique(lengths)
#     474 if len(uniques) > 1:
# --> 475     raise ValueError(
#     476         "Found input variables with inconsistent numbers of samples: %r"
#     477         % [int(l) for l in lengths]
#     478     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1, 90950]
