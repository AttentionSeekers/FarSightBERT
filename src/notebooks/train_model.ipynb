# %%
import os
print(os.getcwd())
os.chdir('..')
# Out:
# /home/trath/Code/nlpvise/src/notebooks

# %%
# !python training_pipeline.py --name load_split_data
# Out:
# 318.00s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Data loaded succesfully.
# Train Test split generated successfully !

# %%
# !python training_pipeline.py --name train_convlstm
