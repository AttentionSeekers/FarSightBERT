# %%
import os
os.chdir('..')
print(os.getcwd())
# Out:
# /home/trath/Code/nlpvise/src

# %%
from training_pipeline import TrainingPipeline
from models.convnet import ConvNet

# %%
MAX_EPOCHS = 10
RANDOM_STATE = 42

# %%
training_pipeline = TrainingPipeline()

# %% [markdown]
# **Load the data and split train test set**

# %%
training_pipeline.load_data()
# Out:
# Data loaded successfully.
# Train Test split generated successfully !

# %% [markdown]
# **Train ConvNet**

# %%
model = ConvNet(input_size=768)
args = { 'max_epochs': MAX_EPOCHS,
         'learning_rate': 0.001,
         'random_state': RANDOM_STATE,
         'batch_size': 128
        }
training_pipeline.train_model(model, args=args)
# Out:
#   0%|          | 0/889 [00:00<?, ?it/s]
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4839       0.0107        0.4707  7.3415
#   0%|          | 0/889 [00:00<?, ?it/s]
#       2        0.4668       0.0110        0.4629  6.8997
#   0%|          | 0/889 [00:00<?, ?it/s]
#       3        0.4610       0.0119        0.4598  9.7998
#   0%|          | 0/889 [00:00<?, ?it/s]
#       4        0.4571       0.0121        0.4588  9.3834
#   0%|          | 0/889 [00:00<?, ?it/s]
#       5        0.4540       0.0123        0.4575  6.8528
#   0%|          | 0/889 [00:00<?, ?it/s]
#       6        0.4515       0.0126        0.4556  9.0280
#   0%|          | 0/889 [00:00<?, ?it/s]
#       7        0.4494       0.0136        0.4541  8.8594
#   0%|          | 0/889 [00:00<?, ?it/s]
#       8        0.4475       0.0133        0.4539  9.4016
#   0%|          | 0/889 [00:00<?, ?it/s]
#       9        0.4458       0.0144        0.4519  6.3417
#   0%|          | 0/889 [00:00<?, ?it/s]
#      10        0.4443       0.0152        0.4522  9.2074
